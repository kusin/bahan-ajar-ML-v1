# %% [markdown]
# # [Intro to Recurrent Neural Networks LSTM | GRU](https://www.kaggle.com/thebrownviking20/intro-to-recurrent-neural-networks-lstm-gru?select=BA_2006-01-01_to_2018-01-01.csv)

# %% [markdown]
# ## Part 1 LSTMs for predicting the price of stocks of IBM for the year 2017

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %%
# Some functions to help out with
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real IBM Stock Price')
    plt.plot(predicted, color='blue',label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
    plt.show()

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
# First, we get the data
dataset = pd.read_csv('D:/Belajar Python/dataset/dataset ibm/IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])
dataset
# Out:
#               Open    High     Low   Close    Volume Name
# Date
# 2006-01-03   82.45   82.55   80.81   82.06  11715200  IBM
# 2006-01-04   82.20   82.50   81.33   81.95   9840600  IBM
# 2006-01-05   81.40   82.90   81.00   82.50   7213500  IBM
# 2006-01-06   83.95   85.03   83.41   84.95   8197400  IBM
# 2006-01-09   84.10   84.25   83.38   83.73   6858200  IBM
# ...            ...     ...     ...     ...       ...  ...
# 2017-12-22  151.82  153.00  151.50  152.50   2990583  IBM
# 2017-12-26  152.51  153.86  152.50  152.83   2479017  IBM
# 2017-12-27  152.95  153.18  152.61  153.13   2149257  IBM
# 2017-12-28  153.20  154.12  153.20  154.04   2687624  IBM
# 2017-12-29  154.17  154.72  153.42  153.42   3327087  IBM
#
# [3020 rows x 6 columns]

# %%
# Checking for missing values
training_set = dataset[:'2016'].iloc[:,1:2].values
training_set.shape
# Out:
# (2769, 1)

# %%
# Checking for missing values
test_set = dataset['2017':].iloc[:,1:2].values
test_set.shape
# Out:
# (251, 1)

# %%
# We have chosen 'High' attribute for prices. Let's see what it looks like
dataset["High"][:'2016'].plot(figsize=(16,4),legend=True)
dataset["High"]['2017':].plot(figsize=(16,4),legend=True)
plt.legend(['Training set (Before 2017)','Test set (2017 and beyond)'])
plt.title('IBM stock price')
plt.show()

# %%
# Scaling the training set
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# view result scaling from training test
training_set_scaled.shape
# Out:
# (2769, 1)

# %%
# Since LSTMs store long term memory state, we create a data structure with 60 timesteps and 1 output
# So for each element of training set, we have 60 previous training set elements 
X_train = []
y_train = []
for i in range(60,2769):
    X_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Reshaping X_train for efficient modelling
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
X_train.shape
# Out:
# (2709, 60, 1)

# %%
# The LSTM architecture
regressor = Sequential()

# First LSTM layer with Dropout regularisation
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))

# Second LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Third LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Fourth LSTM layer
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

# The output layer
regressor.add(Dense(units=1))

# Compiling the RNN
regressor.compile(optimizer='rmsprop',loss='mean_squared_error')

# Fitting to the training set
regressor.fit(X_train,y_train,epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 85/85 [==============================] - 11s 67ms/step - loss: 0.0467
# Epoch 2/50
# 85/85 [==============================] - 5s 61ms/step - loss: 0.0120
# Epoch 3/50
# 85/85 [==============================] - 5s 58ms/step - loss: 0.0091
# Epoch 4/50
# 85/85 [==============================] - 5s 59ms/step - loss: 0.0070
# Epoch 5/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0062
# Epoch 6/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0057
# Epoch 7/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0049
# Epoch 8/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0047
# Epoch 9/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0042
# Epoch 10/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0038
# Epoch 11/50
# 85/85 [==============================] - 5s 58ms/step - loss: 0.0039
# Epoch 12/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0034
# Epoch 13/50
# 85/85 [==============================] - 5s 55ms/step - loss: 0.0031
# Epoch 14/50
# 85/85 [==============================] - 5s 58ms/step - loss: 0.0032
# Epoch 15/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0030
# Epoch 16/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0029
# Epoch 17/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0027
# Epoch 18/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0025
# Epoch 19/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0023
# Epoch 20/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0025
# Epoch 21/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0025
# Epoch 22/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0027
# Epoch 23/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0022
# Epoch 24/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0023
# Epoch 25/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0023
# Epoch 26/50
# 85/85 [==============================] - 5s 55ms/step - loss: 0.0021
# Epoch 27/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0022
# Epoch 28/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0019
# Epoch 29/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0021
# Epoch 30/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0021
# Epoch 31/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0018
# Epoch 32/50
# 85/85 [==============================] - 5s 55ms/step - loss: 0.0018
# Epoch 33/50
# 85/85 [==============================] - 5s 55ms/step - loss: 0.0017
# Epoch 34/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0019
# Epoch 35/50
# 85/85 [==============================] - 5s 55ms/step - loss: 0.0017
# Epoch 36/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0018
# Epoch 37/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0019
# Epoch 38/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0017
# Epoch 39/50
# 85/85 [==============================] - 5s 55ms/step - loss: 0.0015
# Epoch 40/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0016
# Epoch 41/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0017
# Epoch 42/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0015
# Epoch 43/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0016
# Epoch 44/50
# 85/85 [==============================] - 5s 58ms/step - loss: 0.0016
# Epoch 45/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0015
# Epoch 46/50
# 85/85 [==============================] - 5s 55ms/step - loss: 0.0014
# Epoch 47/50
# 85/85 [==============================] - 5s 57ms/step - loss: 0.0015
# Epoch 48/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0015
# Epoch 49/50
# 85/85 [==============================] - 5s 56ms/step - loss: 0.0014
# Epoch 50/50
# 85/85 [==============================] - 5s 55ms/step - loss: 0.0014

# %%
# Now to get the test set ready in a similar way as the training set.
# The following has been done so forst 60 entires of test set have 60 previous values which is impossible to get unless we take the whole 
# 'High' attribute data for processing
dataset_total = pd.concat((dataset["High"][:'2016'],dataset["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# %%
# Preparing X_test and predicting the prices
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
# Visualizing the results for LSTM
plot_predictions(test_set,predicted_stock_price)

# %%
# Evaluating our model
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 3.7928433671852333.

# %% [markdown]
# ## Part 2 GRU for predicting the price of stocks of IBM for the year 2017

# %%
# The GRU architecture
regressorGRU = Sequential()

# First GRU layer with Dropout regularisation
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))

# Second GRU layer
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))

# Third GRU layer
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))

# Fourth GRU layer
regressorGRU.add(GRU(units=50, activation='tanh'))
regressorGRU.add(Dropout(0.2))

# The output layer
regressorGRU.add(Dense(units=1))

# Compiling the RNN
regressorGRU.compile(optimizer=SGD(lr=0.01, decay=1e-7, momentum=0.9, nesterov=False),loss='mean_squared_error')

# Fitting to the training set
regressorGRU.fit(X_train,y_train,epochs=50,batch_size=150)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 7s 142ms/step - loss: 0.1474
# Epoch 2/50
# 19/19 [==============================] - 3s 142ms/step - loss: 0.0462
# Epoch 3/50
# 19/19 [==============================] - 3s 140ms/step - loss: 0.0160
# Epoch 4/50
# 19/19 [==============================] - 3s 143ms/step - loss: 0.0052
# Epoch 5/50
# 19/19 [==============================] - 3s 140ms/step - loss: 0.0048
# Epoch 6/50
# 19/19 [==============================] - 3s 142ms/step - loss: 0.0043
# Epoch 7/50
# 19/19 [==============================] - 3s 142ms/step - loss: 0.0038
# Epoch 8/50
# 19/19 [==============================] - 3s 138ms/step - loss: 0.0038
# Epoch 9/50
# 19/19 [==============================] - 3s 138ms/step - loss: 0.0033
# Epoch 10/50
# 19/19 [==============================] - 3s 141ms/step - loss: 0.0036
# Epoch 11/50
# 19/19 [==============================] - 3s 142ms/step - loss: 0.0030
# Epoch 12/50
# 19/19 [==============================] - 3s 137ms/step - loss: 0.0031
# Epoch 13/50
# 19/19 [==============================] - 3s 136ms/step - loss: 0.0031
# Epoch 14/50
# 19/19 [==============================] - 3s 134ms/step - loss: 0.0036
# Epoch 15/50
# 19/19 [==============================] - 3s 138ms/step - loss: 0.0028
# Epoch 16/50
# 19/19 [==============================] - 3s 138ms/step - loss: 0.0026
# Epoch 17/50
# 19/19 [==============================] - 3s 139ms/step - loss: 0.0028
# Epoch 18/50
# 19/19 [==============================] - 3s 139ms/step - loss: 0.0029
# Epoch 19/50
# 19/19 [==============================] - 3s 139ms/step - loss: 0.0028
# Epoch 20/50
# 19/19 [==============================] - 3s 133ms/step - loss: 0.0027
# Epoch 21/50
# 19/19 [==============================] - 3s 133ms/step - loss: 0.0026
# Epoch 22/50
# 19/19 [==============================] - 3s 135ms/step - loss: 0.0026
# Epoch 23/50
# 19/19 [==============================] - 3s 143ms/step - loss: 0.0027
# Epoch 24/50
# 19/19 [==============================] - 3s 134ms/step - loss: 0.0026
# Epoch 25/50
# 19/19 [==============================] - 3s 134ms/step - loss: 0.0027
# Epoch 26/50
# 19/19 [==============================] - 3s 133ms/step - loss: 0.0024
# Epoch 27/50
# 19/19 [==============================] - 3s 136ms/step - loss: 0.0026
# Epoch 28/50
# 19/19 [==============================] - 3s 133ms/step - loss: 0.0025
# Epoch 29/50
# 19/19 [==============================] - 3s 140ms/step - loss: 0.0024
# Epoch 30/50
# 19/19 [==============================] - 3s 136ms/step - loss: 0.0024
# Epoch 31/50
# 19/19 [==============================] - 3s 137ms/step - loss: 0.0022
# Epoch 32/50
# 19/19 [==============================] - 3s 133ms/step - loss: 0.0025
# Epoch 33/50
# 19/19 [==============================] - 3s 134ms/step - loss: 0.0024
# Epoch 34/50
# 19/19 [==============================] - 3s 132ms/step - loss: 0.0021
# Epoch 35/50
# 19/19 [==============================] - 3s 142ms/step - loss: 0.0021
# Epoch 36/50
# 19/19 [==============================] - 3s 135ms/step - loss: 0.0022
# Epoch 37/50
# 19/19 [==============================] - 3s 132ms/step - loss: 0.0021
# Epoch 38/50
# 19/19 [==============================] - 3s 133ms/step - loss: 0.0024
# Epoch 39/50
# 19/19 [==============================] - 3s 135ms/step - loss: 0.0024
# Epoch 40/50
# 19/19 [==============================] - 3s 133ms/step - loss: 0.0022
# Epoch 41/50
# 19/19 [==============================] - 3s 136ms/step - loss: 0.0021
# Epoch 42/50
# 19/19 [==============================] - 3s 134ms/step - loss: 0.0023
# Epoch 43/50
# 19/19 [==============================] - 3s 134ms/step - loss: 0.0023
# Epoch 44/50
# 19/19 [==============================] - 3s 133ms/step - loss: 0.0022
# Epoch 45/50
# 19/19 [==============================] - 3s 132ms/step - loss: 0.0023
# Epoch 46/50
# 19/19 [==============================] - 3s 132ms/step - loss: 0.0021
# Epoch 47/50
# 19/19 [==============================] - 3s 135ms/step - loss: 0.0019
# Epoch 48/50
# 19/19 [==============================] - 3s 141ms/step - loss: 0.0022
# Epoch 49/50
# 19/19 [==============================] - 3s 135ms/step - loss: 0.0021
# Epoch 50/50
# 19/19 [==============================] - 3s 134ms/step - loss: 0.0021

# %%
# Preparing X_test and predicting the prices
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
GRU_predicted_stock_price = regressorGRU.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)

# %%
# Visualizing the results for GRU
plot_predictions(test_set,GRU_predicted_stock_price)

# %%
# Evaluating GRU
return_rmse(test_set,GRU_predicted_stock_price)
# Out:
# The root mean squared error is 3.3229067632148763.

# %% [markdown]
# ### Sequence Generation

# %%
# Preparing sequence data
initial_sequence = X_train[2708,:]
sequence = []
for i in range(251):
    new_prediction = regressorGRU.predict(initial_sequence.reshape(initial_sequence.shape[1],initial_sequence.shape[0],1))
    initial_sequence = initial_sequence[1:]
    initial_sequence = np.append(initial_sequence,new_prediction,axis=0)
    sequence.append(new_prediction)
sequence = sc.inverse_transform(np.array(sequence).reshape(251,1))

# %%
# Visualizing the sequence
plot_predictions(test_set,sequence)

# %%
# Evaluating the sequence
return_rmse(test_set,sequence)
# Out:
# The root mean squared error is 10.119978708834978.
